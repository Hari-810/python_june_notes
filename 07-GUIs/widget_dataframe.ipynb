# %%
import ipywidgets as widgets

# %%
import numpy as np
import pandas as pd

data =pd.DataFrame(np.random.rand(10,10))

# %%
data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.480686  0.118165  0.282382  0.842779  0.707219  0.113932  0.293319
# 1  0.880243  0.611516  0.473814  0.429930  0.134010  0.349351  0.485706
# 2  0.238178  0.329488  0.005150  0.885807  0.604752  0.957963  0.646388
# 3  0.212119  0.069198  0.680016  0.987993  0.920741  0.988105  0.368876
# 4  0.373433  0.296685  0.375626  0.008035  0.782468  0.253525  0.386800
# 5  0.187374  0.236648  0.033600  0.399709  0.584155  0.270864  0.874714
# 6  0.690357  0.019661  0.586379  0.688442  0.151973  0.106970  0.714301
# 7  0.402562  0.096362  0.508876  0.795655  0.648579  0.948173  0.416185
# 8  0.056740  0.434252  0.282060  0.463081  0.435135  0.582937  0.777086
# 9  0.095401  0.272636  0.237274  0.399305  0.874594  0.412368  0.349301
#
#           7         8         9
# 0  0.027610  0.367172  0.056636
# 1  0.586183  0.644405  0.899057
# 2  0.696458  0.828296  0.323392
# 3  0.139753  0.109915  0.566131
# ...

# %%
widgets.Dropdown(
    options = data[0]
)
# Out:
# Dropdown(options=(0.4806857105647502, 0.8802427388233725, 0.23817801192027976, 0.2121192113335737, 0.373432536…
